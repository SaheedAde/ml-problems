# %%
import schemdraw
from schemdraw import flow

# %matplotlib inline

# %%
with schemdraw.Drawing() as d:
    flow.Start().label('SUPERVISED')
    flow.Arrow().down(d.unit/3)

    cross_validation = flow.Decision(w=5.5, h=4, W='NO', E='YES').label(
        '*CROSS VALIDATION* \n Is the target \n variable balanced?')
    flow.Arrow().left(d.unit/4)
    flow.Arrow().right(d.unit/4)

    # kfold = flow.Box(w=5.5, h=4).label('K-FOLD')


    # flow.Line().down(d.unit/4)
    # flow.Wire('c', k=3.5, arrow='->').to(cross_validation.E)
